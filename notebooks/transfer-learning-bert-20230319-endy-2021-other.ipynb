# %% [markdown]
# ## Merge all dataset into monthly dataset

# %%
import pandas as pd

# %%
#load  Jan 2021 .csv sub-data

data = pd.read_csv('~/Code/giadapi/crypto/data/processed/0_1000_twitter_comments.csv',)
data1 = pd.read_csv('~/Code/giadapi/crypto/data/processed/1000_2000_twitter_comments.csv')
data2 = pd.read_csv('~/Code/giadapi/crypto/data/processed/2000_3000_twitter_comments.csv')
data3 = pd.read_csv('~/Code/giadapi/crypto/data/processed/3000_4000_twitter_comments.csv')
data4 = pd.read_csv('~/Code/giadapi/crypto/data/processed/4000_5000_twitter_comments.csv')
data5 = pd.read_csv('~/Code/giadapi/crypto/data/processed/5000_6000_twitter_comments.csv')
data6 = pd.read_csv('~/Code/giadapi/crypto/data/processed/6000_7000_twitter_comments.csv')
data7 = pd.read_csv('~/Code/giadapi/crypto/data/processed/7000_8000_twitter_comments.csv')
data8 = pd.read_csv('~/Code/giadapi/crypto/data/processed/8000_9000_twitter_comments.csv')
data9 = pd.read_csv('~/Code/giadapi/crypto/data/processed/9000_10000_twitter_comments.csv')
data10 = pd.read_csv('~/Code/giadapi/crypto/data/processed/10000_11000_twitter_comments.csv')
data11 = pd.read_csv('~/Code/giadapi/crypto/data/processed/11000_12000_twitter_comments.csv')
data12 = pd.read_csv('~/Code/giadapi/crypto/data/processed/12000_13000_twitter_comments.csv')
data13 = pd.read_csv('~/Code/giadapi/crypto/data/processed/13000_14000_twitter_comments.csv')
data14 = pd.read_csv('~/Code/giadapi/crypto/data/processed/14000_15000_twitter_comments.csv')
data15 = pd.read_csv('~/Code/giadapi/crypto/data/processed/15000_16000_twitter_comments.csv')
data16 = pd.read_csv('~/Code/giadapi/crypto/data/processed/16000_16219_twitter_comments.csv')

# %%
# merge all sub-data

data = data.append(data1)
data = data.append(data2)
data = data.append(data3)
data = data.append(data4)
data = data.append(data5)
data = data.append(data6)
data = data.append(data7)
data = data.append(data8)
data = data.append(data9)
data = data.append(data10)
data = data.append(data11)
data = data.append(data12)
data = data.append(data13)
data = data.append(data14)
data = data.append(data15)
data = data.append(data16)
# Out:
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_10265/797897537.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data1)
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_10265/797897537.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data2)
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_10265/797897537.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data3)
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_10265/797897537.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(data4)
# ...

# %%
data['negative_bert'] = data.text
data['neutral_bert'] = data.text
data['positive_bert'] = data.text

# %%
data
# Out:
#      Unnamed: 0                                       process_text  \
# 0         14003  Wohhhh is great!!!!!   Pls give some suvenir f...
# 1         14004  Well  made a joke about #dodgecoin and #Bitcoi...
# 2         14005  It's about inequality and unfair markets. Taxe...
# 3         14006  #affiliatemarketing #affiliate #travel #touris...
# 4         14007  #tumblr #twitter #gifting #facebook #instagram...
# ..          ...                                                ...
# 213       16214  Bitcoin mined blocks distribution per pool in ...
# 214       16215  Bitcoin free space in mined blocks in last wee...
# 215       16216  Bitcoin free space in mined blocks in last day...
# 216       16217  Bitcoin mined blocks distribution per pool in ...
# 217       16218  Bitcoin mined blocks distribution per pool in ...
#
#                                             text  \
# 0    [2.2661212e-04 5.1470011e-01 4.8507327e-01]
# 1             [0.01004564 0.47907194 0.5108824 ]
# ...

# %% [markdown]
# ## Save the dataset into .csv

# %%
start_date = data['date'][0]
start_date

# %%
file_name = f"{start_date}_{end_date}_twitter_comments.csv"
data.to_csv(f"~/code/giadapi/crypto/data/processed/{file_name}")
