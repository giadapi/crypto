# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
data1 = pd.read_csv('../raw_data/2022-06-24_2022-08-12_twitter_comments.csv', lineterminator='\n')
data2 = pd.read_csv('../raw_data/2022-06-24_2022-08-12_twitter_transferlearning.csv', lineterminator='\n')
data3 = pd.read_csv('../raw_data/2022-06-24_2023-03-08_BTC-USD_1d.csv', lineterminator='\n')

# %%
data1.shape
# Out:
# (4905, 14)

# %%
data2.head()
# Out:
#    Unnamed: 0        date  count_negative_xlm  count_neutral_xlm  \
# 0           0  2022-06-24                   6                 57
# 1           1  2022-06-25                   8                 73
# 2           2  2022-06-26                   6                 63
# 3           3  2022-06-27                  17                 68
# 4           4  2022-06-28                  10                 68
#
#    count_positive_xlm  count_negative_bert  count_neutral_bert  \
# 0                  15                    3                  51
# 1                  10                    5                  55
# 2                  16                    5                  38
# 3                  14                   14                  59
# 4                  23                   11                  44
#
#    count_positive_bert  negative_xlm  neutral_xlm  positive_xlm  \
# 0                   24     10.757743    48.626522     18.615738
# ...

# %%
data3.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2022-06-24  21084.648438  21472.917969  20777.511719  21231.656250
# 1  2022-06-25  21233.609375  21520.914062  20964.585938  21502.337891
# 2  2022-06-26  21496.494141  21783.724609  21016.269531  21027.294922
# 3  2022-06-27  21028.238281  21478.089844  20620.199219  20735.478516
# 4  2022-06-28  20731.544922  21164.423828  20228.812500  20280.634766
#
#       Adj Close       Volume   Symbol  price_change
# 0  21231.656250  24957784918  BTC-USD           NaN
# 1  21502.337891  18372538715  BTC-USD      0.012749
# 2  21027.294922  18027170497  BTC-USD     -0.022093
# 3  20735.478516  20965695707  BTC-USD     -0.013878
# 4  20280.634766  21381535161  BTC-USD     -0.021936

# %%
matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,8))

sns.lineplot(data = data3['Close'], marker='o', sort = False, ax=ax1)
ax2 = ax1.twinx()

sns.barplot(data = data2, x=data2['date'], y=data2['count_positive_bert'], alpha=0.5, ax=ax2)
# Out:
# <Axes: xlabel='date', ylabel='count_positive_bert'>

# %%
sns.lineplot(data = data3['Close'], marker='o', sort = False)
# Out:
# <Axes: ylabel='Close'>
