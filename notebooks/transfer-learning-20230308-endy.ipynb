# %% [markdown]
# Transfer learning using cryptobert and roberta

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer, AutoConfig, TextClassificationPipeline
from transformers import pipeline
import numpy as np
import pandas as pd
from scipy.special import softmax
import datetime

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /Users/endy/.pyenv/versions/3.10.6/envs/crypto/lib/python3.10/site-packages (1.13.1)
# Requirement already satisfied: typing-extensions in /Users/endy/.pyenv/versions/3.10.6/envs/crypto/lib/python3.10/site-packages (from torch) (4.5.0)

# %%
# !pip install protobuf==3.20.0
# Out:
# Requirement already satisfied: protobuf==3.20.0 in /Users/endy/.pyenv/versions/3.10.6/envs/crypto/lib/python3.10/site-packages (3.20.0)

# %% [markdown]
# ## Step 1 - Importing a sample of some Bitcoin Tweet Data to begin analysing the model

# %%
# 20230308 - test data from twitter api, from 20220624 to 20220812 
data = pd.read_csv('~/Code/giadapi/crypto/data/tweets_20220624_20220812.csv')

# 20230307 - test data from kaggle
# data = pd.read_csv('~/code/giadapi/crypto/data/raw/bitcoin_tweets1000000.csv', nrows = 1000)
# "\\wsl.localhost\Ubuntu\home\peter\code\giadapi\crypto\kaggle-tweets.zip"

# %%
data
# Out:
#                 author id                 created_at geo                   id  \
# 0     1538620097975267328  2022-06-24 06:09:58+00:00      1540215638651797504
# 1              3017689166  2022-06-24 06:09:55+00:00      1540215626815647746
# 2     1439292574645334020  2022-06-24 06:09:52+00:00      1540215613754589184
# 3     1155038365881782272  2022-06-24 06:09:46+00:00      1540215588638920704
# 4     1098733905849417728  2022-06-24 06:09:46+00:00      1540215586998722561
# ...                   ...                        ...  ..                  ...
# 4900  1448763322812276737  2022-08-12 14:08:18+00:00      1558093020536442882
# 4901             77002234  2022-08-12 14:08:15+00:00      1558093008112943107
# 4902  1514825067800449025  2022-08-12 14:08:05+00:00      1558092966727921664
# 4903  1082726807919415296  2022-08-12 14:08:02+00:00      1558092951246741507
# 4904           2403989244  2022-08-12 14:08:00+00:00      1558092945877762048
#
#      lang  like_count  quote_count  reply_count  retweet_count  \
# 0      en           2            0            1              0
# 1      en           0            1            0              0
# 2      en           1            0            0              0
# 3      en           0            0            0              0
# 4      en           0            0            0              0
# ...   ...         ...          ...          ...            ...
# 4900   en           0            0            0              0
# 4901   en           0            0            1              0
# 4902   en           0            0            0              0
# 4903   en           0            0            1              0
# 4904   en          13            0            2              3
#
#                                                   tweet
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
# [4905 rows x 10 columns]

# %%
#only run it if the dataset is from Twitter API
data['text'] = data[['tweet']]
data['date'] = data[['created_at']]

# %%
data = data[['text', 'date']]

# %%
data['text'][0]
# Out:
# "I'm looking for these levels today 👀 \n\n#Bitcoin #Ethereum #Solana #MATIC #Cryptocurency #ETH #BTC #TradingView https://t.co/L1SMaXRQiY"

# %% [markdown]
# ## Step 2 - Cleaning the data

# %%
# Preprocess text (username and link placeholders) - this is suggested from the example in 
# https://huggingface.co/cardiffnlp/twitter-xlm-roberta-base-sentiment
def preprocess_1(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

preprocess_1(data['text'][0])
# Out:
# "I'm looking for these levels today 👀 \n\n#Bitcoin #Ethereum #Solana #MATIC #Cryptocurency #ETH #BTC #TradingView http"

# %%
# I have changed this to remove more information

def preprocess_2(text):
    new_text = []
    for t in text.split(" "):
        t = '' if t.startswith('@') and len(t) > 1 else t
        t = '' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

sample_text = preprocess_2(data['text'][0])
sample_text
# Out:
# "I'm looking for these levels today 👀 \n\n#Bitcoin #Ethereum #Solana #MATIC #Cryptocurency #ETH #BTC #TradingView "

# %%
#use the preprocess_2 to clean the data

data['process_text'] = data.text
data['label_xlm'] = data.text
# data['score_xlm'] = data.text
data['negative_xlm'] = data.text
data['neutral_xlm'] = data.text
data['positive_xlm'] = data.text

data['label_bert'] = data.text
# data['score_bert'] = data.text
data['negative_bert'] = data.text
data['neutral_bert'] = data.text
data['positive_bert'] = data.text
for i in range(len(data)):
    data['process_text'][i] = preprocess_2(data['text'][i])
# Out:
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['process_text'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label_xlm'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['negative_xlm'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['neutral_xlm'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['positive_xlm'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label_bert'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['negative_bert'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['neutral_bert'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['positive_bert'] = data.text
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/3150124772.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['process_text'][i] = preprocess_2(data['text'][i])

# %% [markdown]
# ## Step 3 - analyse the language and sentiments by pretrained model

# %%
# !pyenv local crypto

# %%
#Model 1a - Use the xlm model - https://huggingface.co/cardiffnlp/twitter-xlm-roberta-base-sentiment?text=go+up

model_path_xlm = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
sentiment_task_xlm = pipeline("sentiment-analysis", model=model_path_xlm, tokenizer=model_path_xlm)

# %%
test_sent = sentiment_task_xlm(sample_text)
print(test_sent[0]['score'])
print(test_sent[0]['label'])
# Out:
# 0.8055609464645386
# neutral

# %%
#Model 1b - Use the xlm model, with full score
MODEL_xlm = f"{model_path_xlm}"
tokenizer_xlm = AutoTokenizer.from_pretrained(MODEL_xlm)
config_xlm = AutoConfig.from_pretrained(MODEL_xlm)

# PT
model_xlm = AutoModelForSequenceClassification.from_pretrained(MODEL_xlm)
# model_xlm.save_pretrained(MODEL_xlm)

# %%
def scores_xlm(x):
    encoded_input_xlm = tokenizer_xlm(x, return_tensors='pt')
    output_xlm = model_xlm(**encoded_input_xlm)
    scores_xlm = output_xlm[0][0].detach().numpy()
    scores_xlm = softmax(scores_xlm) #1st score is negative, 2nd score is netural, 3rd score is positive
    return scores_xlm

# %%
score = scores_xlm(sample_text)
score
# Out:
# array([0.03531584, 0.80556095, 0.15912327], dtype=float32)

# %%
#Model 2a - Use the CryptoBERT model - https://huggingface.co/cardiffnlp/twitter-xlm-roberta-base-sentiment?text=go+up

model_path_bert = "ElKulako/cryptobert"
sentiment_task_bert = pipeline("sentiment-analysis", model=model_path_bert, tokenizer=model_path_bert)

# %%
test_sent = sentiment_task_bert(sample_text)
print(test_sent[0]['score'])
print(test_sent[0]['label'])
# Out:
# 0.5417445302009583
# Neutral

# %%
#Model 2b - Use the bert model, with full scores
MODEL_bert = f"{model_path_bert}"
tokenizer_bert = AutoTokenizer.from_pretrained(MODEL_bert)
config_bert = AutoConfig.from_pretrained(MODEL_bert)

# PT
model_bert = AutoModelForSequenceClassification.from_pretrained(MODEL_bert)
# model_bert.save_pretrained(MODEL_bert)

# %%
def scores_bert(sample_text):
    encoded_input_bert = tokenizer_bert(sample_text, return_tensors='pt')
    output_bert = model_bert(**encoded_input_bert)
    scores_bert = output_bert[0][0].detach().numpy()
    scores_bert = softmax(scores_bert) #1st score is negative, 2nd score is netural, 3rd score is positive
    return scores_bert

# %%
score = scores_bert(sample_text)
score
# Out:
# array([3.1575037e-04, 5.4174453e-01, 4.5793974e-01], dtype=float32)

# %%
data
# Out:
#                                                    text  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                            date  \
# 0     2022-06-24 06:09:58+00:00
# 1     2022-06-24 06:09:55+00:00
# 2     2022-06-24 06:09:52+00:00
# 3     2022-06-24 06:09:46+00:00
# 4     2022-06-24 06:09:46+00:00
# ...                         ...
# 4900  2022-08-12 14:08:18+00:00
# 4901  2022-08-12 14:08:15+00:00
# 4902  2022-08-12 14:08:05+00:00
# 4903  2022-08-12 14:08:02+00:00
# 4904  2022-08-12 14:08:00+00:00
#
#                                            process_text  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from  zes...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                               label_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                            negative_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                             neutral_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                            positive_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                              label_bert  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                           negative_bert  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                            neutral_bert  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                                           positive_bert
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
# [4905 rows x 11 columns]

# %%
for i in range(len(data)):
    sentiment_xlm = sentiment_task_xlm(data['process_text'][i])
    data['label_xlm'][i] = sentiment_xlm[0]['label']
#     data['score_xlm'][i] = sentiment_xlm[0]['score']
    score_xlm = scores_xlm(data['process_text'][i])
    data['negative_xlm'][i] = score_xlm[0]
    data['neutral_xlm'][i] = score_xlm[1]
    data['positive_xlm'][i] = score_xlm[2]
    
    sentiment_bert = sentiment_task_bert(data['process_text'][i])
    data['label_bert'][i] = sentiment_bert[0]['label']
#     data['score_bert'][i] = sentiment_bert[0]['score']
    score_bert = scores_bert(data['process_text'][i])
    data['negative_bert'][i] = score_bert[0]
    data['neutral_bert'][i] = score_bert[1]
    data['positive_bert'][i] = score_bert[2]
# Out:
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label_xlm'][i] = sentiment_xlm[0]['label']
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['negative_xlm'][i] = score_xlm[0]
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['neutral_xlm'][i] = score_xlm[1]
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['positive_xlm'][i] = score_xlm[2]
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['label_bert'][i] = sentiment_bert[0]['label']
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['negative_bert'][i] = score_bert[0]
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['neutral_bert'][i] = score_bert[1]
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1845661372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['positive_bert'][i] = score_bert[2]

# %%
data
# Out:
#                                                    text  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                            date  \
# 0     2022-06-24 06:09:58+00:00
# 1     2022-06-24 06:09:55+00:00
# 2     2022-06-24 06:09:52+00:00
# 3     2022-06-24 06:09:46+00:00
# 4     2022-06-24 06:09:46+00:00
# ...                         ...
# 4900  2022-08-12 14:08:18+00:00
# 4901  2022-08-12 14:08:15+00:00
# 4902  2022-08-12 14:08:05+00:00
# 4903  2022-08-12 14:08:02+00:00
# 4904  2022-08-12 14:08:00+00:00
#
#                                            process_text label_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...   neutral
# 1     create twitter tasks and pay with #bitcoin #et...   neutral
# 2     Top 10 Cyptocurrencies in the World by Twitter...   neutral
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...  positive
# 4     I am claiming my free Lightning sats from  zes...   neutral
# ...                                                 ...       ...
# 4900  👋 A new block was found on the #Bitcoin networ...   neutral
# 4901  Byzantine Generals are back on campus. #byzant...   neutral
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...   neutral
# 4903  Trade-Ideas Trading Room is opening now - join...   neutral
# 4904  Today #BitcoinCash can process about 8 000 000...   neutral
#
#      negative_xlm neutral_xlm positive_xlm label_bert negative_bert  \
# 0        0.035316    0.805561     0.159123    Neutral      0.000316
# 1        0.032351    0.829668     0.137981    Bullish      0.000407
# 2        0.179284    0.696499     0.124217    Neutral      0.000707
# 3        0.028341    0.124245     0.847414    Neutral      0.000268
# 4         0.05642    0.780599      0.16298    Neutral      0.001384
# ...           ...         ...          ...        ...           ...
# 4900     0.044105    0.782324     0.173571    Bullish      0.005152
# 4901     0.052524    0.595462     0.352014    Neutral      0.000143
# 4902     0.067207     0.86844     0.064353    Neutral      0.022624
# 4903     0.016118     0.79939     0.184492    Neutral      0.000213
# 4904     0.041351    0.717406     0.241244    Bullish      0.007625
#
#      neutral_bert positive_bert
# 0        0.541745       0.45794
# 1        0.434556      0.565037
# 2        0.863628      0.135665
# 3        0.510206      0.489527
# 4        0.640739      0.357877
# ...           ...           ...
# 4900     0.434237      0.560612
# 4901      0.65811      0.341748
# 4902     0.603121      0.374255
# 4903     0.806042      0.193745
# 4904     0.218519      0.773856
#
# [4905 rows x 11 columns]

# %% [markdown]
# ## Step 4 - compare the model performance

# %%
def standardise(x):
    if (x == 'Neutral'):
        return 'neutral'
    elif (x == 'Bullish'):
        return 'positive'
    else:
        return 'negative'
data["label_bert"] = data["label_bert"].apply(standardise)
# Out:
# /var/folders/d5/bxgljmg10q70y4xmy233dhfr0000gn/T/ipykernel_79762/1388689369.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["label_bert"] = data["label_bert"].apply(standardise)

# %%
data
# Out:
#                                                    text  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                            date  \
# 0     2022-06-24 06:09:58+00:00
# 1     2022-06-24 06:09:55+00:00
# 2     2022-06-24 06:09:52+00:00
# 3     2022-06-24 06:09:46+00:00
# 4     2022-06-24 06:09:46+00:00
# ...                         ...
# 4900  2022-08-12 14:08:18+00:00
# 4901  2022-08-12 14:08:15+00:00
# 4902  2022-08-12 14:08:05+00:00
# 4903  2022-08-12 14:08:02+00:00
# 4904  2022-08-12 14:08:00+00:00
#
#                                            process_text label_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...   neutral
# 1     create twitter tasks and pay with #bitcoin #et...   neutral
# 2     Top 10 Cyptocurrencies in the World by Twitter...   neutral
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...  positive
# 4     I am claiming my free Lightning sats from  zes...   neutral
# ...                                                 ...       ...
# 4900  👋 A new block was found on the #Bitcoin networ...   neutral
# 4901  Byzantine Generals are back on campus. #byzant...   neutral
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...   neutral
# 4903  Trade-Ideas Trading Room is opening now - join...   neutral
# 4904  Today #BitcoinCash can process about 8 000 000...   neutral
#
#      negative_xlm neutral_xlm positive_xlm label_bert negative_bert  \
# 0        0.035316    0.805561     0.159123    neutral      0.000316
# 1        0.032351    0.829668     0.137981   positive      0.000407
# 2        0.179284    0.696499     0.124217    neutral      0.000707
# 3        0.028341    0.124245     0.847414    neutral      0.000268
# 4         0.05642    0.780599      0.16298    neutral      0.001384
# ...           ...         ...          ...        ...           ...
# 4900     0.044105    0.782324     0.173571   positive      0.005152
# 4901     0.052524    0.595462     0.352014    neutral      0.000143
# 4902     0.067207     0.86844     0.064353    neutral      0.022624
# 4903     0.016118     0.79939     0.184492    neutral      0.000213
# 4904     0.041351    0.717406     0.241244   positive      0.007625
#
#      neutral_bert positive_bert
# 0        0.541745       0.45794
# 1        0.434556      0.565037
# 2        0.863628      0.135665
# 3        0.510206      0.489527
# 4        0.640739      0.357877
# ...           ...           ...
# 4900     0.434237      0.560612
# 4901      0.65811      0.341748
# 4902     0.603121      0.374255
# 4903     0.806042      0.193745
# 4904     0.218519      0.773856
#
# [4905 rows x 11 columns]

# %%
data['equality'] = data['label_xlm'] == data['label_bert']

# %%
data
# Out:
#                                                    text  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                            date  \
# 0     2022-06-24 06:09:58+00:00
# 1     2022-06-24 06:09:55+00:00
# 2     2022-06-24 06:09:52+00:00
# 3     2022-06-24 06:09:46+00:00
# 4     2022-06-24 06:09:46+00:00
# ...                         ...
# 4900  2022-08-12 14:08:18+00:00
# 4901  2022-08-12 14:08:15+00:00
# 4902  2022-08-12 14:08:05+00:00
# 4903  2022-08-12 14:08:02+00:00
# 4904  2022-08-12 14:08:00+00:00
#
#                                            process_text label_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...   neutral
# 1     create twitter tasks and pay with #bitcoin #et...   neutral
# 2     Top 10 Cyptocurrencies in the World by Twitter...   neutral
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...  positive
# 4     I am claiming my free Lightning sats from  zes...   neutral
# ...                                                 ...       ...
# 4900  👋 A new block was found on the #Bitcoin networ...   neutral
# 4901  Byzantine Generals are back on campus. #byzant...   neutral
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...   neutral
# 4903  Trade-Ideas Trading Room is opening now - join...   neutral
# 4904  Today #BitcoinCash can process about 8 000 000...   neutral
#
#      negative_xlm neutral_xlm positive_xlm label_bert negative_bert  \
# 0        0.035316    0.805561     0.159123    neutral      0.000316
# 1        0.032351    0.829668     0.137981   positive      0.000407
# 2        0.179284    0.696499     0.124217    neutral      0.000707
# 3        0.028341    0.124245     0.847414    neutral      0.000268
# 4         0.05642    0.780599      0.16298    neutral      0.001384
# ...           ...         ...          ...        ...           ...
# 4900     0.044105    0.782324     0.173571   positive      0.005152
# 4901     0.052524    0.595462     0.352014    neutral      0.000143
# 4902     0.067207     0.86844     0.064353    neutral      0.022624
# 4903     0.016118     0.79939     0.184492    neutral      0.000213
# 4904     0.041351    0.717406     0.241244   positive      0.007625
#
#      neutral_bert positive_bert  equality
# 0        0.541745       0.45794      True
# 1        0.434556      0.565037     False
# 2        0.863628      0.135665      True
# 3        0.510206      0.489527     False
# 4        0.640739      0.357877      True
# ...           ...           ...       ...
# 4900     0.434237      0.560612     False
# 4901      0.65811      0.341748      True
# 4902     0.603121      0.374255      True
# 4903     0.806042      0.193745      True
# 4904     0.218519      0.773856     False
#
# [4905 rows x 12 columns]

# %%
data['label_xlm'].value_counts()
# Out:
# neutral     3614
# positive     789
# negative     502
# Name: label_xlm, dtype: int64

# %%
data['label_bert'].value_counts()
# Out:
# neutral     2916
# positive    1674
# negative     315
# Name: label_bert, dtype: int64

# %%
data['equality'].value_counts()
# Out:
# True     2693
# False    2212
# Name: equality, dtype: int64

# %% [markdown]
# ## Step 5: Count the total number of labels/scores (positive, negative vs neutral) by date

# %%
data['date'] = pd.to_datetime(data.date)
data['new_date'] = data['date'].dt.date

# %%
data
# Out:
#                                                    text  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...
# 1     create twitter tasks and pay with #bitcoin #et...
# 2     Top 10 Cyptocurrencies in the World by Twitter...
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...
# 4     I am claiming my free Lightning sats from @_bi...
# ...                                                 ...
# 4900  👋 A new block was found on the #Bitcoin networ...
# 4901  Byzantine Generals are back on campus. #byzant...
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...
# 4903  Trade-Ideas Trading Room is opening now - join...
# 4904  Today #BitcoinCash can process about 8 000 000...
#
#                           date  \
# 0    2022-06-24 06:09:58+00:00
# 1    2022-06-24 06:09:55+00:00
# 2    2022-06-24 06:09:52+00:00
# 3    2022-06-24 06:09:46+00:00
# 4    2022-06-24 06:09:46+00:00
# ...                        ...
# 4900 2022-08-12 14:08:18+00:00
# 4901 2022-08-12 14:08:15+00:00
# 4902 2022-08-12 14:08:05+00:00
# 4903 2022-08-12 14:08:02+00:00
# 4904 2022-08-12 14:08:00+00:00
#
#                                            process_text label_xlm  \
# 0     I'm looking for these levels today 👀 \n\n#Bitc...   neutral
# 1     create twitter tasks and pay with #bitcoin #et...   neutral
# 2     Top 10 Cyptocurrencies in the World by Twitter...   neutral
# 3     #Airdrop #Airdrops #Airdropinspector #BSC #Cyb...  positive
# 4     I am claiming my free Lightning sats from  zes...   neutral
# ...                                                 ...       ...
# 4900  👋 A new block was found on the #Bitcoin networ...   neutral
# 4901  Byzantine Generals are back on campus. #byzant...   neutral
# 4902  📉 $BTC / $USDT Shorted(Sell) $23773.50\n[14:08...   neutral
# 4903  Trade-Ideas Trading Room is opening now - join...   neutral
# 4904  Today #BitcoinCash can process about 8 000 000...   neutral
#
#      negative_xlm neutral_xlm positive_xlm label_bert negative_bert  \
# 0        0.035316    0.805561     0.159123    neutral      0.000316
# 1        0.032351    0.829668     0.137981   positive      0.000407
# 2        0.179284    0.696499     0.124217    neutral      0.000707
# 3        0.028341    0.124245     0.847414    neutral      0.000268
# 4         0.05642    0.780599      0.16298    neutral      0.001384
# ...           ...         ...          ...        ...           ...
# 4900     0.044105    0.782324     0.173571   positive      0.005152
# 4901     0.052524    0.595462     0.352014    neutral      0.000143
# 4902     0.067207     0.86844     0.064353    neutral      0.022624
# 4903     0.016118     0.79939     0.184492    neutral      0.000213
# 4904     0.041351    0.717406     0.241244   positive      0.007625
#
#      neutral_bert positive_bert  equality    new_date
# 0        0.541745       0.45794      True  2022-06-24
# 1        0.434556      0.565037     False  2022-06-24
# 2        0.863628      0.135665      True  2022-06-24
# 3        0.510206      0.489527     False  2022-06-24
# 4        0.640739      0.357877      True  2022-06-24
# ...           ...           ...       ...         ...
# 4900     0.434237      0.560612     False  2022-08-12
# 4901      0.65811      0.341748      True  2022-08-12
# 4902     0.603121      0.374255      True  2022-08-12
# 4903     0.806042      0.193745      True  2022-08-12
# 4904     0.218519      0.773856     False  2022-08-12
#
# [4905 rows x 13 columns]

# %%
grouped_data = pd.DataFrame(data.groupby(['new_date'])['label_xlm'].value_counts().unstack().fillna(0).reset_index())
grouped_data = grouped_data.rename_axis("", axis="columns")

grouped_data_bert = pd.DataFrame(data.groupby(['new_date'])['label_bert'].value_counts().unstack().fillna(0).reset_index())
grouped_score = pd.DataFrame(data.groupby(['new_date'])[['negative_xlm', 'neutral_xlm', 'positive_xlm','negative_bert', 'neutral_bert', 'positive_bert']].sum().fillna(0).reset_index())

grouped_data[['date', 'count_negative_xlm', 'count_neutral_xlm', 'count_positive_xlm']] = grouped_data[['new_date', 'negative', 'neutral', 'positive']]
grouped_data[['count_negative_bert', 'count_neutral_bert', 'count_positive_bert']] = grouped_data_bert[['negative', 'neutral', 'positive']]
grouped_data[['negative_xlm', 'neutral_xlm', 'positive_xlm','negative_bert', 'neutral_bert', 'positive_bert']] = grouped_score[['negative_xlm', 'neutral_xlm', 'positive_xlm','negative_bert', 'neutral_bert', 'positive_bert']]

grouped_data = grouped_data.drop(["new_date", 'negative', 'neutral', 'positive'], axis='columns')

# %%
grouped_data
# Out:
#           date  count_negative_xlm  count_neutral_xlm  count_positive_xlm  \
# 0   2022-06-24                   6                 57                  15
# 1   2022-06-25                   8                 73                  10
# 2   2022-06-26                   6                 63                  16
# 3   2022-06-27                  17                 68                  14
# 4   2022-06-28                  10                 68                  23
# 5   2022-06-29                   9                 57                  12
# 6   2022-06-30                  13                 65                  17
# 7   2022-07-01                  10                 65                  24
# 8   2022-07-02                  11                 82                   9
# 9   2022-07-03                   3                 60                  13
# 10  2022-07-04                  21                 69                  18
# 11  2022-07-05                  10                 76                  18
# 12  2022-07-06                   7                 73                  15
# 13  2022-07-07                  14                 72                  14
# 14  2022-07-08                  14                 68                  19
# 15  2022-07-09                  10                 73                  17
# 16  2022-07-10                   7                 59                  19
# 17  2022-07-11                   8                 60                  19
# 18  2022-07-12                  13                 72                  13
# 19  2022-07-13                  14                 68                  13
# 20  2022-07-14                  10                 58                  21
# 21  2022-07-15                   4                 78                  10
# 22  2022-07-16                   9                 77                  14
# 23  2022-07-17                  13                 71                  12
# 24  2022-07-18                  10                 75                  18
# 25  2022-07-19                  16                 69                  21
# 26  2022-07-20                  14                 73                  20
# 27  2022-07-21                  15                 74                  15
# 28  2022-07-22                   9                 76                  17
# 29  2022-07-23                  11                 71                  20
# 30  2022-07-24                   1                 89                  13
# 31  2022-07-25                  13                 66                   9
# 32  2022-07-26                   8                 73                  25
# 33  2022-07-27                  15                 81                  14
# 34  2022-07-28                  12                 73                  18
# 35  2022-07-29                  11                 79                  18
# 36  2022-07-30                  12                 75                  20
# 37  2022-07-31                   9                 66                  26
# 38  2022-08-01                   3                 81                  20
# 39  2022-08-02                   8                 81                  14
# 40  2022-08-03                  17                 80                  11
# 41  2022-08-04                   7                 84                  17
# 42  2022-08-05                   7                 85                  14
# 43  2022-08-06                   6                 71                  15
# 44  2022-08-07                   5                 79                  17
# 45  2022-08-08                  11                 82                  14
# 46  2022-08-09                   9                 94                   9
# 47  2022-08-10                  12                 85                  12
# 48  2022-08-11                  10                 58                   9
# 49  2022-08-12                   4                 62                   8
#
#     count_negative_bert  count_neutral_bert  count_positive_bert  \
# 0                     3                  51                   24
# 1                     5                  55                   31
# 2                     5                  38                   42
# 3                    14                  59                   26
# 4                    11                  44                   46
# 5                    12                  45                   21
# 6                    10                  50                   35
# 7                    10                  63                   26
# 8                    14                  64                   24
# 9                     3                  54                   19
# 10                   12                  57                   39
# 11                    6                  60                   38
# 12                    5                  56                   34
# 13                   10                  59                   31
# 14                    7                  68                   26
# 15                    5                  64                   31
# 16                    5                  47                   33
# 17                    9                  54                   24
# 18                    8                  60                   30
# 19                    3                  61                   31
# 20                    7                  52                   30
# 21                    3                  60                   29
# 22                    4                  60                   36
# 23                    4                  58                   34
# 24                    8                  55                   40
# 25                    6                  70                   30
# 26                   15                  58                   34
# 27                    4                  72                   28
# 28                    7                  60                   35
# 29                    3                  55                   44
# 30                    2                  50                   51
# 31                    1                  53                   34
# 32                    4                  62                   40
# 33                    7                  66                   37
# 34                    9                  57                   37
# 35                   11                  56                   41
# 36                    6                  57                   44
# 37                    3                  59                   39
# 38                    3                  64                   37
# 39                    4                  70                   29
# 40                    8                  64                   36
# 41                    3                  70                   35
# 42                    5                  74                   27
# 43                    3                  55                   34
# 44                    5                  59                   37
# 45                    3                  66                   38
# 46                    8                  69                   35
# 47                    7                  69                   33
# 48                    1                  48                   28
# 49                    4                  39                   31
#
#     negative_xlm  neutral_xlm  positive_xlm  negative_bert  neutral_bert  \
# 0      10.757743    48.626522     18.615738       4.843230     43.021858
# 1      12.396420    57.172752     21.430817       4.944597     47.671741
# 2       9.410669    51.040672     24.548651       3.567415     42.689507
# 3      20.643763    55.461174     22.895071      12.516508     50.333969
# 4      16.376936    58.804665     25.818392       9.588241     48.004971
# 5      12.726689    47.485916     17.787397       8.710379     41.640835
# 6      18.186152    52.810375     24.003471       8.194161     49.909798
# 7      15.544599    56.053684     27.401722       8.109880     55.050465
# 8      15.372499    67.569374     19.058142      11.698927     54.279682
# 9       9.674458    48.017109     18.308447       3.834375     44.462799
# 10     22.185198    60.283188     25.531614      11.742633     54.103210
# 11     14.923321    62.324924     26.751768       5.857553     56.443127
# 12     11.814151    58.713741     24.472099       5.482796     52.135170
# 13     16.859270    58.831059     24.309671       8.489388     53.321423
# 14     16.729851    58.438709     25.831453       6.839923     55.414932
# 15     15.036494    58.539127     26.424374       6.032089     55.713505
# 16     12.515890    48.765358     23.718760       6.591109     43.815811
# 17     12.508650    50.662434     23.828907       8.495831     46.859802
# 18     17.774508    58.081207     22.144278       8.501574     53.494553
# 19     18.256170    54.686237     22.057589       3.407999     54.193901
# 20     13.387864    51.695988     23.916151       5.086719     48.202534
# 21     11.771262    58.616070     21.612665       4.132136     51.157097
# 22     14.999740    59.948357     25.051912       5.219924     53.924648
# 23     14.912628    58.063534     23.023834       5.356705     51.828320
# 24     14.520728    62.924953     25.554308       8.306188     51.873348
# 25     19.467299    60.194744     26.337975       6.302600     58.365276
# 26     19.652864    60.986938     26.360205      13.034338     54.767036
# 27     20.110924    59.328434     24.560646       3.878155     57.896118
# 28     14.531067    61.063595     26.405357       6.723382     54.475399
# 29     14.961634    62.120987     24.917379       4.578745     55.759499
# 30      9.910026    67.022194     26.067799       2.763852     52.841984
# 31     16.199972    51.519966     20.280064       2.147589     49.557022
# 32     16.040789    60.319530     29.639687       5.571520     57.482975
# 33     20.066847    66.415451     23.517704       6.414419     58.116886
# 34     16.040798    60.636711     26.322500       8.471820     51.654591
# 35     15.962055    65.658493     26.379465       9.607628     54.244286
# 36     16.678289    63.658901     26.662809       6.352705     55.870945
# 37     14.032178    59.799122     27.168692       3.429469     54.471355
# 38     11.972843    66.154099     25.873066       3.789042     54.628944
# 39     12.452245    68.249168     22.298567       4.325021     55.625992
# 40     21.218513    67.299004     19.482470       8.149933     55.587036
# 41     13.452865    70.963173     23.583965       4.081872     61.562237
# 42     12.285117    73.320190     20.394703       4.776183     61.044815
# 43     11.666819    59.880589     20.452583       4.434540     48.221783
# 44     11.832351    66.233215     22.934429       5.706671     52.284729
# 45     17.286396    68.498276     21.215315       3.422684     59.170502
# 46     14.432463    75.887924     21.679628       9.339688     57.946957
# 47     16.169012    70.805901     22.025087       5.306245     60.884026
# 48     12.984107    49.323696     14.692189       1.548846     44.153683
# 49      8.012236    51.540237     14.447524       4.081648     35.923859
#
#     positive_bert
# 0       30.134912
# 1       38.383656
# 2       38.743065
# 3       36.149529
# 4       43.406780
# 5       27.648781
# 6       36.896053
# 7       35.839645
# 8       36.021385
# 9       27.702829
# 10      42.154156
# 11      41.699337
# 12      37.382042
# 13      38.189190
# 14      38.745144
# 15      38.254429
# 16      34.593079
# 17      31.644373
# 18      36.003876
# 19      37.398117
# 20      35.710732
# 21      36.710762
# 22      40.855438
# 23      38.814987
# 24      42.820469
# 25      41.332127
# 26      39.198631
# 27      42.225719
# 28      40.801220
# 29      41.661751
# 30      47.394157
# 31      36.295383
# 32      42.945499
# 33      45.468685
# 34      42.873589
# 35      44.148087
# 36      44.776348
# 37      43.099171
# 38      45.582001
# 39      43.048996
# 40      44.263035
# 41      42.355885
# 42      40.178993
# 43      39.343678
# 44      43.008591
# 45      44.406807
# 46      44.713360
# 47      42.809731
# 48      31.297461
# 49      33.994495

# %% [markdown]
# ## Step 6 - Download the data

# %%
start_date = grouped_data['date'][0]
start_date_str = datetime.datetime.strftime(start_date, "%Y-%m-%d")
start_date_str
# Out:
# '2022-06-24'

# %%
end_date = grouped_data['date'][len(grouped_data)-1]
end_date_str = datetime.datetime.strftime(end_date, "%Y-%m-%d")
end_date_str
# Out:
# '2022-08-12'

# %%
file_name = f"{start_date_str}_{end_date_str}_twitter_comments.csv"
data.to_csv(f"~/code/giadapi/crypto/data/processed/{file_name}")

# %%
file_name = f"{start_date_str}_{end_date_str}_twitter_transferlearning.csv"
grouped_data.to_csv(f"~/code/giadapi/crypto/data/processed/{file_name}")
